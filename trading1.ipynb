# %%
import yfinance as yf
data = yf.download('AAPL', start="2017-04-01", end="2019-04-30")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-03-31  143.720001  144.270004  143.009995  143.660004  137.828171
# 2017-04-03  143.710007  144.119995  143.050003  143.699997  137.866547
# 2017-04-04  143.250000  144.889999  143.169998  144.770004  138.893127
# 2017-04-05  144.220001  145.460007  143.809998  144.020004  138.173553
# 2017-04-06  144.289993  144.520004  143.449997  143.660004  137.828171
#
#               Volume
# Date
# 2017-03-31  19661700
# 2017-04-03  19985700
# 2017-04-04  19891400
# 2017-04-05  27717900
# 2017-04-06  21149000

# %%
# import pandas as pd
# data = pd.read_csv('FB.csv')
# data.head()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
data.index = pd.to_datetime(data.index, dayfirst=True)

# %%
# Visualise the data
plt.figure(figsize=(10,5))
data['Close'].plot(figsize=(10,5))
plt.legend()
plt.show()
